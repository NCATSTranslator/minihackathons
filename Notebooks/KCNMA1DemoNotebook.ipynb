# %%
import json
import requests
import urllib
import copy

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display

# %%
def submit_to_ars(m,ars_url='https://ars.transltr.io/ars/api',arax_url='https://arax.ncats.io/legacy'):
    submit_url=f'{ars_url}/submit'
    response = requests.post(submit_url,json=m)
    try:
        message_id = response.json()['pk']
    except:
        print('fail')
        message_id = None
    print(f'{arax_url}/?source=ARS&id={message_id}')
    return message_id

def retrieve_ars_results(mid,ars_url='https://ars.transltr.io/ars/api'):
    message_url = f'{ars_url}/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    print( j['status'] )
    results = {}
    for child in j['children']:
        print(child['status'])
        if child['status']  == 'Done':
            childmessage_id = child['message']
            child_url = f'{ars_url}/messages/{childmessage_id}'
            try:
                child_response = requests.get(child_url).json()
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except Exception as e:
                nresults=0
                child['status'] = 'ARS Error'
        elif child['status'] == 'Error':
            nresults=0
            childmessage_id = child['message']
            child_url = f'{ars_url}/messages/{childmessage_id}'
            try:
                child_response = requests.get(child_url).json()
                results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except Exception as e:
                print(e)
                child['status'] = 'ARS Error'
        else:
            nresults = 0
        print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def submit_to_devars(m):
    return submit_to_ars(m,ars_url='https://ars-dev.transltr.io/ars/api',arax_url='https://arax.ncats.io')

def retrieve_devars_results(m):
    return retrieve_ars_results(m,ars_url='https://ars-dev.transltr.io/ars/api')

def submit_to_ciars(m):
    return submit_to_ars(m,ars_url='https://ars.ci.transltr.io/ars/api',arax_url='https://arax.ncats.io')

def retrieve_ciars_results(m):
    return retrieve_ars_results(m,ars_url='https://ars.ci.transltr.io/ars/api')

# %%
def printjson(j):
    print(json.dumps(j,indent=4))

def print_json(j):
    printjson(j)

# %%
def parse(json):
    keylist = list(json.keys())
    for key in keylist:
        if key in KEYS:
            if (isinstance(json[KEYS.get(key)],dict)):
                parse(json[key])
        elif (isinstance(json[key],dict)):
            parse(json[key])

# %%
def name_lookup(text):
    url= f'https://name-resolution-sri.renci.org/lookup?string={text}&offset=0&limit=10'
    response = requests.post(url)
    printjson(response.json())

# %%
def one_hop_message(subject_category,object_category,predicate=None,subject_id = None, object_id = None):
    query_graph = {
    "nodes": {
        'a':{
            "category": subject_category
        },
        'b':{
            "category": object_category
        }
    },
    "edges": {
        'ab':{
            "subject": "a",
            "object": "b",
            #"predicate": predicate
        }
    }
    }
    if predicate is not None:
        query_graph['edges']['ab']['predicate'] = predicate
    if subject_id is not None:
        query_graph['nodes']['a']['id'] = subject_id
    if object_id is not None:
        query_graph['nodes']['b']['id'] = object_id
    message = {"message": {"query_graph": query_graph},'knowledge_graph':{"nodes": [], "edges": [],}, 'results':[]}
    return message

# %%
def keys_exist(element, *keys):
    if not isinstance(element, dict):
        raise AttributeError('keys_exists() expects dict as first argument.')
    if len(keys) == 0:
        raise AttributeError('keys_exists() expects at least two arguments, one given.')

    _element = element
    for key in keys:
        try:
            _element = _element[key]
            if _element is None:
                return False
        except KeyError:
            return False
    return True

def get_safe(element,*keys):
    '''
    :param element: JSON to be processed
    :param keys: list of keys in order to be traversed. e.g. "fields","data","message","results
    :return: the value of the terminal key if present or None if not
    '''
    if element is None:
        return None
    _element = element
    for key in keys:
        try:
            _element = _element[key]
            if _element is None:
                return None
            if key == keys[-1]:
                return _element
        except KeyError:
            return None
    return None

# %%
'''
This pulls approved drugs by pulling the MAX_FDA_APPROVAL_PHASE string from the description of the node
This is by no means a complete solution and I should touch base with Vlado about the implementation of 
FDA approval data from MolePro for a more complete solution.
'''

def get_approved(results):
    approved = []
    for r in results:
        nodes = get_safe(result[r],"message","knowledge_graph","nodes")
        if nodes is not None:
            for node in nodes:
                attributes = get_safe(nodes[node],"attributes")
                if attributes is not None:
                    for attribute in attributes:
                        if("original_attribute_name" in attribute):
                            if(attribute["original_attribute_name"]=="description"):
                                if("MAX_FDA_APPROVAL_PHASE: 4" in attribute["value"]):
                                    approved.append(node)
    return approved

# %%
def synonymize(ids, url="https://nodenormalization-sri.renci.org/1.1/get_normalized_nodes"):
        if( isinstance(ids,str) ):
            ids = [ids]
        params = {"curie":ids}
        url_curies = urllib.parse.urlencode(params, True)
        syn_url=url+"?"+url_curies
        syn_response=requests.get(syn_url)
        synonyms= syn_response.json()
        return synonyms

# %%
def create_synonym_table(messages):
    synonyms={}
    for message in messages.values():
        nodes = get_safe(message,"message","knowledge_graph","nodes")
        if nodes is not None:
            sym = synonymize(nodes)
            if(len(synonyms)==0):
                synonyms= sym
            else:
                absent = []
                for node in nodes:
                    if(node in synonyms.items()):
                        continue
                    else:
                        absent.append(node)
                absent_syms = synonymize(absent)
                synonyms.update(absent_syms)
    return synonyms

# %%
def create_synonym_tables(messages):
    synonyms={}
    for entry in messages:
        actor = entry
        message = messages[actor]
        nodes = get_safe(message,"message","knowledge_graph","nodes")
        if nodes is not None:
            sym = synonymize(nodes)
            synonyms[actor]=sym
    return synonyms

# %%
def canonical_id_lists(synonym_tables):
    pks ={}
    for entry in synonym_tables:
        pks[entry]=[]
        for k,v in synonym_tables[entry].items():
            if v is None:
                pks[entry].append(k)
            else:
                canonical_id=v["id"]["identifier"]
                if (canonical_id not in pks[entry]):
                    pks[entry].append(canonical_id)
    return pks

# %%
def get_consensus_nodes(canonical_id_lists):
    consensus={}
    canon = copy.deepcopy(canonical_id_lists)
    my_keys= canon.keys()
    my_values=canon.values()
    for actor, id_list in canonical_id_lists.items():
        for actor2, id_list2 in canon.items():
            #Surely, there is a better way to do this with slices or something
            if(actor==actor2):
                continue
            else:
                s1 = set(id_list)
                s2 = set(id_list2)
                inter = (s1 & s2)
                if (inter):
                    for node in inter:
                        if node in consensus.keys():
                            consensus[node].add(actor)
                            consensus[node].add(actor2)
                        else:
                            consensus[node]={actor,actor2}      
        canon.pop(actor,None)
    return consensus

# %% [markdown]
# # KCNMA1

# %%
kcq={
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids": [
                        "HGNC:6284"
                    ],
                    "categories": [
                        "biolink:Gene"
                    ]
                },
                "n1": {
		             "categories":[
                         "biolink:ChemicalSubstance"
                        ]
                }
            },
            "edges": {
                "e0": {
                    "subject": "n0",
                    "object": "n1"

                }
            }
        }
    }
}

# %%
kcresult = submit_to_devars(kcq)
# Out:
# https://arax.ncats.io/?source=ARS&id=94f6b020-9a30-45c2-9a32-75eb9e8dff9a

# %%
result = retrieve_devars_results(kcresult)
# Out:
# Done
# Done
# Done ara-aragorn 871
# Done
# Done ara-arax 100
# Done
# Done ara-bte 181
# Done
# Done ara-unsecret 152
# Done
# Done kp-genetics 0
# Done
# Done kp-molecular 99
# Done
# Done ara-explanatory 0
# Done
# Done ara-improving 5
# Done
# Done kp-cam 0
# Done
# Done kp-textmining 0
# Done
# Done kp-openpredict 0
# Done
# ARS Error kp-cohd 0
# Error
# Error kp-chp 0
# Done
# Done kp-icees 0
# Done
# Done kp-icees-dili 0

# %%
syns = create_synonym_tables(result)

# %%
canon = canonical_id_lists(syns)
con = get_consensus_nodes(canon)       
print (len(con))
# Out:
# 227

# %%
for k in sorted(con,key=lambda k: len(con[k]),reverse=True):
    print(k, con[k])
# Out:
# PUBCHEM.COMPOUND:5413 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:5560 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:9951995 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:4552 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:4189 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:3226 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:3639 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:3019 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:2315 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:3647 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:3562 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:4914 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:2733 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:2993 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# PUBCHEM.COMPOUND:5573 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular'}
# NCBIGene:3778 {'ara-unsecret', 'ara-aragorn', 'ara-bte', 'kp-molecular', 'ara-improving'}
# PUBCHEM.COMPOUND:445070 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# PUBCHEM.COMPOUND:5071 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# UMLS:C0243071 {'ara-arax', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5284513 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# PUBCHEM.COMPOUND:10177784 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# PUBCHEM.COMPOUND:1400 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# PUBCHEM.COMPOUND:3062316 {'ara-arax', 'ara-unsecret', 'ara-aragorn', 'kp-molecular'}
# PUBCHEM.COMPOUND:65970 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5757 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:52948538 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:214350 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4697 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2720 {'kp-molecular', 'ara-bte', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6674 {'kp-molecular', 'ara-unsecret', 'ara-aragorn', 'ara-improving'}
# MESH:C403585 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5311 {'ara-arax', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5997 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:446512 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:7111 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:133058 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:444899 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2812 {'ara-arax', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2726 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:244 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5280450 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6918632 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# MESH:D024363 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:281 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:105008 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:7471 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# MESH:C025964 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16247 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:702 {'ara-arax', 'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2724 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5359476 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16133816 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11228183 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16132435 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9826528 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6708801 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:123631 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3995234 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:57448257 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6439848 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2176 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10109069 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:146018878 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9956637 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5311330 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:25154867 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9943465 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:609483 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:71815 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2252 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:73707420 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9935249 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11317348 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:62389 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3947 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# GTOPDB:2306 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5032 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:42611257 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5284550 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:21678144 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6710776 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5311281 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3066 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:129989 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:753704 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:8433 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5311454 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5318562 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:49849931 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4707 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5092098 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3012 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:60953 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:656731 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4698 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3292447 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:60490 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16759175 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5281565 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:151165 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:127382 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5479 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3672 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11072143 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16404350 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:25059310 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:15548 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9600409 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10420710 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:36462 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:24768935 {'kp-molecular', 'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:71398 {'ara-arax', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL136478 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:115267 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:439423 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:73078 {'ara-arax', 'ara-aragorn'}
# RXNORM:1311633 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:712 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:22326046 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:91474 {'ara-arax', 'ara-aragorn'}
# VANDF:4017424 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:131609 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:68740552 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4362 {'ara-arax', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL2146121 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11462834 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5281847 {'ara-arax', 'ara-aragorn'}
# VANDF:4021546 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:24341 {'ara-arax', 'ara-aragorn'}
# CHEBI:27026 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:31388 {'ara-arax', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL2109588 {'ara-arax', 'ara-aragorn'}
# CHEMBL.TARGET:CHEMBL3545434 {'ara-arax', 'ara-aragorn'}
# UMLS:C1514152 {'ara-arax', 'ara-aragorn'}
# DRUGBANK:DB02577 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:27503 {'ara-arax', 'ara-aragorn'}
# MONDO:0012276 {'ara-arax', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL2108350 {'ara-arax', 'ara-aragorn'}
# DRUGBANK:DB15127 {'ara-arax', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10038562 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10064074 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11779066 {'ara-bte', 'ara-aragorn'}
# CHEBI:24852 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10243969 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11335564 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11472034 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11109578 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4826 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:271 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3605484 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:56635390 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:24285063 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2798243 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2882 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:813 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:44570449 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16099761 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11042812 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10035337 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5839 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:24285062 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:54614868 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9881289 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:15717694 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:24892745 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10354434 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:9815734 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2946791 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10356396 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2953683 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11471747 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:4050379 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5460341 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11065065 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10083014 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10398337 {'ara-bte', 'ara-aragorn'}
# CHEBI:36314 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5073804 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10263172 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11302540 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11392406 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10969679 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10968747 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11254734 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:390361 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5280352 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11437030 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11000844 {'ara-bte', 'ara-aragorn'}
# UNII:42VZT0U6YR {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11782023 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16099762 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11820396 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:11818496 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:10967695 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3283 {'ara-bte', 'ara-aragorn'}
# PUBCHEM.COMPOUND:2798242 {'ara-bte', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL2104381 {'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:6041 {'ara-unsecret', 'ara-aragorn'}
# CHEMBL.COMPOUND:CHEMBL2096655 {'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:3826 {'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:5313082 {'ara-unsecret', 'ara-aragorn'}
# PUBCHEM.COMPOUND:16758101 {'ara-aragorn', 'ara-improving'}
# CHEMBL.COMPOUND:CHEMBL3039061 {'ara-aragorn', 'ara-improving'}
# PUBCHEM.COMPOUND:2975 {'ara-aragorn', 'ara-improving'}
# PUBCHEM.COMPOUND:1548076 {'ara-aragorn', 'ara-improving'}
# PUBCHEM.COMPOUND:57125363 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:10836 {'ara-arax', 'ara-bte'}
# CHEBI:26995 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:46878365 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:5354027 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:118212070 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:2343 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:444732 {'ara-arax', 'ara-bte'}
# CHEBI:38093 {'ara-arax', 'ara-bte'}
# MESH:D000631 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:222786 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:5754 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:3894 {'ara-arax', 'ara-bte'}
# MESH:D024506 {'ara-arax', 'ara-bte'}
# UMLS:C0721205 {'ara-arax', 'ara-bte'}
# CHEBI:24870 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:520535 {'ara-arax', 'ara-bte'}
# UMLS:C0304437 {'ara-arax', 'ara-bte'}
# MESH:D007038 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:403 {'ara-arax', 'ara-bte'}
# PUBCHEM.COMPOUND:6442063 {'ara-arax', 'ara-bte'}
# UMLS:C0175817 {'ara-bte', 'ara-unsecret'}

# %%
approved_list = get_approved(result)
# Out:
# ['CHEMBL.COMPOUND:CHEMBL1015',
#  'CHEMBL.COMPOUND:CHEMBL104',
#  'CHEMBL.COMPOUND:CHEMBL1054',
#  'CHEMBL.COMPOUND:CHEMBL112570',
#  'CHEMBL.COMPOUND:CHEMBL1131',
#  'CHEMBL.COMPOUND:CHEMBL1201039',
#  'CHEMBL.COMPOUND:CHEMBL1201201',
#  'CHEMBL.COMPOUND:CHEMBL1255',
#  'CHEMBL.COMPOUND:CHEMBL1257',
#  'CHEMBL.COMPOUND:CHEMBL136478',
#  'CHEMBL.COMPOUND:CHEMBL1371',
#  'CHEMBL.COMPOUND:CHEMBL1421',
#  'CHEMBL.COMPOUND:CHEMBL1616046',
#  'CHEMBL.COMPOUND:CHEMBL1684',
#  'CHEMBL.COMPOUND:CHEMBL1763',
#  'CHEMBL.COMPOUND:CHEMBL181',
#  'CHEMBL.COMPOUND:CHEMBL2108350',
#  'CHEMBL.COMPOUND:CHEMBL2146121',
#  'CHEMBL.COMPOUND:CHEMBL313972',
#  'CHEMBL.COMPOUND:CHEMBL333826',
#  'CHEMBL.COMPOUND:CHEMBL389621',
#  'CHEMBL.COMPOUND:CHEMBL424',
#  'CHEMBL.COMPOUND:CHEMBL435',
#  'CHEMBL.COMPOUND:CHEMBL545',
#  'CHEMBL.COMPOUND:CHEMBL569',
#  'CHEMBL.COMPOUND:CHEMBL71',
#  'CHEMBL.COMPOUND:CHEMBL71595',
#  'CHEMBL.COMPOUND:CHEMBL720',
#  'CHEMBL.COMPOUND:CHEMBL74',
#  'CHEMBL.COMPOUND:CHEMBL91',
#  'CHEMBL.COMPOUND:CHEMBL931',
#  'CHEMBL.COMPOUND:CHEMBL959',
#  'CHEMBL.COMPOUND:CHEMBL98']
